# %% [markdown]
# ## **Producing Visualizations**

# %%
#Importing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#2005-06 Data
#Prices
ugd4_p0 = pd.read_csv('Data Files/Uganda - Food Prices (2005-06).csv')
ugd4_p0 = ugd4_p0[ugd4_p0["u"] == "Kg"]
ugd4_p = pd.pivot_table(ugd4_p0, values="price", index=["j","u"], columns=["t","m"] , aggfunc="median")
#Food Expenditures
ugd4_x0 = pd.read_csv('Data Files/Uganda - Food Expenditures (2005-06).csv')
ugd4_x0['i'] = ugd4_x0['i'].astype(str)
ugd4_x = pd.pivot_table(ugd4_x0, values="Expenditure", index=["i","t","m"], columns="j" , aggfunc="median")
#Consumption
ugd4_x_long = ugd4_x.stack().reset_index(name="Expenditure")
ugd4_p_long = ugd4_p0
ugd4_c = ugd4_x_long.merge(ugd4_p_long, on=["j", "t", "m"], how="left")
ugd4_c["Consumption"] = ugd4_c["Expenditure"] / ugd4_c["price"]
ugd4_c = ugd4_c.pivot_table(values="Consumption", index=["i","t","m","u"], columns="j", aggfunc="sum")
#HH Characteristics
ugd_z0 = pd.read_csv('Data Files/Uganda - Household Characteristics.csv')
ugd4_z = ugd_z0[ugd_z0['t'] == '2005-06']
ugd4_z = ugd4_z.set_index(['i','t','m'])
ugd4_z.columns.name = 'k'
ugd4_z.fillna(0, inplace=True)

# %%
#2009-10 Data
#Prices
ugd2_p0 = pd.read_csv('Data Files/Uganda - Food Prices (2009-10).csv')
ugd2_p0 = ugd2_p0[ugd2_p0["u"] == "Kg"]
ugd2_p = pd.pivot_table(ugd2_p0, values="price", index=["j","u"], columns=["t","m"] , aggfunc="median")
#Food Expenditures
ugd2_x0 = pd.read_csv('Data Files/Uganda - Food Expenditures (2009-10).csv')
ugd2_x0['i'] = ugd2_x0['i'].astype(str)
ugd2_x = pd.pivot_table(ugd2_x0, values="Expenditure", index=["i","t","m"], columns="j" , aggfunc="median")
#Consumption
ugd2_x_long = ugd2_x.stack().reset_index(name="Expenditure")  # Ensure values are in a column
ugd2_p_long = ugd2_p0
ugd2_c = ugd2_x_long.merge(ugd2_p_long, on=["j", "t", "m"], how="left")
ugd2_c["Consumption"] = ugd2_c["Expenditure"] / ugd2_c["price"]
ugd2_c = ugd2_c.pivot_table(values="Consumption", index=["i","t","m","u"], columns="j", aggfunc="sum")
#HH Characteristics
ugd2_z = ugd_z0[ugd_z0['t'] == '2009-10']
ugd2_z = ugd2_z.set_index(['i','t','m'])
ugd2_z.columns.name = 'k'
ugd2_z.fillna(0, inplace=True)

# %%
#2010-11 Data
#Prices
ugd5_p0 = pd.read_csv('Data Files/Uganda - Food Prices (2010-11).csv')
ugd5_p0 = ugd5_p0[ugd5_p0["u"] == "Kg"]
ugd5_p = pd.pivot_table(ugd5_p0, values="price", index=["j","u"], columns=["t","m"] , aggfunc="median")
#Food Expenditures
ugd5_x0 = pd.read_csv('Data Files/Uganda - Food Expenditures (2010-11).csv')
ugd5_x0['i'] = ugd5_x0['i'].astype(str)
ugd5_x = pd.pivot_table(ugd5_x0, values="Expenditure", index=["i","t","m"], columns="j" , aggfunc="median")
#Consumption
ugd5_x_long = ugd5_x.stack().reset_index(name="Expenditure")
ugd5_p_long = ugd5_p0
ugd5_c = ugd5_x_long.merge(ugd5_p_long, on=["j", "t", "m"], how="left")
ugd5_c["Consumption"] = ugd5_c["Expenditure"] / ugd5_c["price"]
ugd5_c = ugd5_c.pivot_table(values="Consumption", index=["i","t","m","u"], columns="j", aggfunc="sum")
#HH Characteristics
ugd5_z = ugd_z0[ugd_z0['t'] == '2010-11']
ugd5_z = ugd5_z.set_index(['i','t','m'])
ugd5_z.columns.name = 'k'
ugd5_z.fillna(0, inplace=True)

# %%
#2011-12 Data
#Prices
ugd3_p0 = pd.read_csv('Data Files/Uganda - Food Prices (2011-12).csv')
ugd3_p0 = ugd3_p0[ugd3_p0["u"] == "Kg"]
ugd3_p = pd.pivot_table(ugd3_p0, values="price", index=["j","u"], columns=["t","m"] , aggfunc="median")
#Food Expenditures
ugd3_x0 = pd.read_csv('Data Files/Uganda - Food Expenditures (2011-12).csv')
ugd3_x0['i'] = ugd3_x0['i'].astype(str)
ugd3_x = pd.pivot_table(ugd3_x0, values="Expenditure", index=["i","t","m"], columns="j" , aggfunc="median")
#Consumption
ugd3_x_long = ugd3_x.stack().reset_index(name="Expenditure")
ugd3_p_long = ugd3_p0
ugd3_c = ugd3_x_long.merge(ugd3_p_long, on=["j", "t", "m"], how="left")
ugd3_c["Consumption"] = ugd3_c["Expenditure"] / ugd3_c["price"]
ugd3_c = ugd3_c.pivot_table(values="Consumption", index=["i","t","m","u"], columns="j", aggfunc="sum")
#HH Characteristics
ugd3_z = ugd_z0[ugd_z0['t'] == '2011-12']
ugd3_z = ugd3_z.set_index(['i','t','m'])
ugd3_z.columns.name = 'k'
ugd3_z.fillna(0, inplace=True)

# %%
#2013-14 Data
#Prices
ugd6_p0 = pd.read_csv('Data Files/Uganda - Food Prices (2013-14).csv')
ugd6_p0 = ugd6_p0[ugd6_p0["u"] == "Kg"]
ugd6_p = pd.pivot_table(ugd6_p0, values="price", index=["j","u"], columns=["t","m"] , aggfunc="median")
#Food Expenditures
ugd6_x0 = pd.read_csv('Data Files/Uganda - Food Expenditures (2013-14).csv')
ugd6_x0['i'] = ugd6_x0['i'].astype(str)
ugd6_x = pd.pivot_table(ugd6_x0, values="Expenditure", index=["i","t","m"], columns="j" , aggfunc="median")
#Consumption
ugd6_x_long = ugd6_x.stack().reset_index(name="Expenditure")
ugd6_p_long = ugd6_p0
ugd6_c = ugd6_x_long.merge(ugd6_p_long, on=["j", "t", "m"], how="left")
ugd6_c["Consumption"] = ugd6_c["Expenditure"] / ugd6_c["price"]
ugd6_c = ugd6_c.pivot_table(values="Consumption", index=["i","t","m","u"], columns="j", aggfunc="sum")
#HH Characteristics
ugd6_z = ugd_z0[ugd_z0['t'] == '2013-14']
ugd6_z = ugd6_z.set_index(['i','t','m'])
ugd6_z.columns.name = 'k'
ugd6_z.fillna(0, inplace=True)

# %%
#2015-16 Data
#Prices
ugd_p0 = pd.read_csv('Data Files/Uganda - Food Prices (2015-16).csv')
ugd_p = pd.pivot_table(ugd_p0, values="price", index=["j","u"], columns=["t","m"] , aggfunc="median")
#Food Expenditures
ugd_x0 = pd.read_csv('Data Files/Uganda - Food Expenditures (2015-16).csv')
ugd_x = pd.pivot_table(ugd_x0, values="Expenditure", index=["i","t","m"], columns="j" , aggfunc="median")
#Consumption
ugd_x_long = ugd_x.stack().reset_index(name="Expenditure")
ugd_p_long = ugd_p0
ugd_c = ugd_x_long.merge(ugd_p_long, on=["j", "t", "m"], how="left")
ugd_c["Consumption"] = ugd_c["Expenditure"] / ugd_c["price"]
ugd_c = ugd_c.pivot_table(values="Consumption", index=["i","t","m","u"], columns="j", aggfunc="sum")
#HH Characteristics
ugd_z = ugd_z0[ugd_z0['t'] == '2015-16']
ugd_z = ugd_z.set_index(['i','t','m'])
ugd_z.fillna(0, inplace=True)
ugd_z.columns.name = 'k'

# %%
#2018-19 Data
#Prices
ugd7_p0 = pd.read_csv('Data Files/Uganda - Food Prices (2018-19).csv')
ugd7_p0 = ugd7_p0[ugd7_p0["u"] == "Kg"]
ugd7_p = pd.pivot_table(ugd7_p0, values="price", index=["j","u"], columns=["t","m"] , aggfunc="median")
#Food Expenditures
ugd7_x0 = pd.read_csv('Data Files/Uganda - Food Expenditures (2018-19).csv')
ugd7_x0['i'] = ugd7_x0['i'].astype(str)
ugd7_x = pd.pivot_table(ugd7_x0, values="Expenditure", index=["i","t","m"], columns="j" , aggfunc="median")
#Consumption
ugd7_x_long = ugd7_x.stack().reset_index(name="Expenditure")
ugd7_p_long = ugd7_p0
ugd7_c = ugd7_x_long.merge(ugd7_p_long, on=["j", "t", "m"], how="left")
ugd7_c["Consumption"] = ugd7_c["Expenditure"] / ugd7_c["price"]
ugd7_c = ugd7_c.pivot_table(values="Consumption", index=["i","t","m","u"], columns="j", aggfunc="sum")
#HH Characteristics
ugd7_z = ugd_z0[ugd_z0['t'] == '2018-19']
ugd7_z = ugd7_z.set_index(['i','t','m'])
ugd7_z.columns.name = 'k'
ugd7_z.fillna(0, inplace=True)

# %%
#2019-20 Data
#Prices
ugd8_p0 = pd.read_csv('Data Files/Uganda - Food Prices (2019-20).csv')
ugd8_p0 = ugd8_p0[ugd8_p0["u"] == "Kg"]
ugd8_p = pd.pivot_table(ugd8_p0, values="price", index=["j","u"], columns=["t","m"] , aggfunc="median")
#Food Expenditures
ugd8_x0 = pd.read_csv('Data Files/Uganda - Food Expenditures (2019-20).csv')
ugd8_x0['i'] = ugd8_x0['i'].astype(str)
ugd8_x = pd.pivot_table(ugd8_x0, values="Expenditure", index=["i","t","m"], columns="j" , aggfunc="median")
#Consumption
ugd8_x_long = ugd8_x.stack().reset_index(name="Expenditure")  # Ensure values are in a column
ugd8_p_long = ugd8_p0
ugd8_c = ugd8_x_long.merge(ugd8_p_long, on=["j", "t", "m"], how="left")
ugd8_c["Consumption"] = ugd8_c["Expenditure"] / ugd8_c["price"]
ugd8_c = ugd8_c.pivot_table(values="Consumption", index=["i","t","m","u"], columns="j", aggfunc="sum")
#HH Characteristics
ugd8_z = ugd_z0[ugd_z0['t'] == '2019-20']
ugd8_z = ugd8_z.set_index(['i','t','m'])
ugd8_z.columns.name = 'k'
ugd8_z.fillna(0, inplace=True)

# %%
#FCT and RDI
#FCT
ugd_fct = pd.read_csv('Data Files/Uganda - FCT.csv')
ugd_fct = ugd_fct.rename(columns={"index":"j"}).set_index(["j"])
ugd_fct.columns.name = 'n'
#RDI
ugd_rdi = pd.read_csv('Data Files/Uganda - RDA.csv')
ugd_rdi = ugd_rdi.set_index(["n"])
ugd_rdi.columns.name = 'k'

# %% [markdown]
# ### Average Expenditures

# %%
#05-06 Avg Expenditure
row_sums4 = ugd4_x.sum(axis=1)
mean_row_sum4 = row_sums4.mean()
#09-10 Avg Expenditure
row_sums2 = ugd2_x.sum(axis=1)
mean_row_sum2 = row_sums2.mean()
#10-11 Avg Expenditure
row_sums5 = ugd5_x.sum(axis=1)
mean_row_sum5 = row_sums5.mean()
#11-12 Avg Expenditure
row_sums3 = ugd3_x.sum(axis=1)
mean_row_sum3 = row_sums3.mean()
#13-14 Avg Expenditure
row_sums6 = ugd6_x.sum(axis=1)
mean_row_sum6 = row_sums6.mean()
#15-16 Avg Expenditure
row_sums1 = ugd_x.sum(axis=1)
mean_row_sum1 = row_sums1.mean()
#18-19 Avg Expenditure
row_sums7 = ugd7_x.sum(axis=1)
mean_row_sum7 = row_sums7.mean()
#19-20 Avg Expenditure
row_sums8 = ugd8_x.sum(axis=1)
mean_row_sum8 = row_sums8.mean()

# %%
# Create a DataFrame for plotting
data = {'Year': ['2005-06', '2009-10', '2010-11', '2011-12', '2013-14', '2015-16', '2018-19', '2019-20'], 
    'Mean Expenditure': [mean_row_sum4, mean_row_sum2, mean_row_sum5, mean_row_sum3, mean_row_sum6, mean_row_sum1, mean_row_sum7, mean_row_sum8]
       }

avgexp_df = pd.DataFrame(data)

# Plot the bar graph
plt.figure(figsize=(8, 5))
sns.barplot(x='Year', y='Mean Expenditure', data=avgexp_df, hue='Year', palette='Blues', legend=False)

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Average Expenditure (UGX)')
plt.title('Average Expenditure Over the Years')

# Show the plot
plt.show()

# %% [markdown]
# ### Most Consumed Foods

# %%
#05-06 Consumption by food, descending
column_sums4 = ugd4_c.sum()
sorted_sums4 = column_sums4.sort_values(ascending=False)
#09-10 Consumption by food, descending
column_sums2 = ugd2_c.sum()
sorted_sums2 = column_sums2.sort_values(ascending=False)
#10-11 Consumption by food, descending
column_sums5 = ugd5_c.sum()
sorted_sums5 = column_sums5.sort_values(ascending=False)
#11-12 Consumption by food, descending
column_sums3 = ugd3_c.sum()
sorted_sums3 = column_sums3.sort_values(ascending=False)
#13-14 Consumption by food, descending
column_sums6 = ugd6_c.sum()
sorted_sums6 = column_sums6.sort_values(ascending=False)
#15-16 Consumption by food, descending
column_sums1 = ugd_c.sum()
sorted_sums1 = column_sums1.sort_values(ascending=False)
#18-19 Consumption by food, descending
column_sums7 = ugd7_c.sum()
sorted_sums7 = column_sums7.sort_values(ascending=False)
#19-20 Consumption by food, descending
column_sums8 = ugd8_c.sum()
sorted_sums8 = column_sums8.sort_values(ascending=False)

# %%
# Dictionary of sorted consumption Series for each year
consumption_by_year = {
    '2005-06': sorted_sums4,
    '2009-10': sorted_sums2,
    '2010-11': sorted_sums5,
    '2011-12': sorted_sums3,
    '2013-14': sorted_sums6,
    '2015-16': sorted_sums1,
    '2018-19': sorted_sums7,
    '2019-20': sorted_sums8,
}

# Create a DataFrame to hold top food consumption over time
top_foods = set()
for year, series in consumption_by_year.items():
    top10 = series.head(10)
    top_foods.update(top10.index)

# Convert set to list for indexing
top_foods_list = list(top_foods)

# Use reindex to handle missing foods safely
cons_data = {
    year: series.reindex(top_foods_list)
    for year, series in consumption_by_year.items()
}

# Build DataFrame: rows are years, columns are food items
cons_df = pd.DataFrame(cons_data).T

# Plotting
plt.figure(figsize=(12, 8))
for food in cons_df.columns:
    plt.plot(cons_df.index, cons_df[food], marker='o', label=food)

plt.title('Top 10 Most Consumed Foods Over Time')
plt.xlabel('Year')
plt.ylabel('Total Consumption (Kg)')
plt.xticks(rotation=45)
plt.legend(title='Food Item', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
# Select the top 10 most consumed foods
top_10_foods4 = sorted_sums4.nlargest(10)
# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_foods4.values, y=top_10_foods4.index, hue=top_10_foods4.index, palette="Blues_r", legend=False)
# Labels and title
plt.xlabel("Total Consumption (Kg)")
plt.ylabel("Food Name")
plt.title("Top 10 Most Consumed Foods: 2005-06")
plt.show()

# %%
# Select the top 10 most consumed foods
top_10_foods2 = sorted_sums2.nlargest(10)
# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_foods2.values, y=top_10_foods2.index, hue=top_10_foods2.index, palette="Blues_r", legend=False)
# Labels and title
plt.xlabel("Total Consumption (Kg)")
plt.ylabel("Food Name")
plt.title("Top 10 Most Consumed Foods: 2009-10")
plt.show()

# %%
# Select the top 10 most consumed foods
top_10_foods5 = sorted_sums5.nlargest(10)
# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_foods5.values, y=top_10_foods5.index, hue=top_10_foods5.index, palette="Blues_r", legend=False)
# Labels and title
plt.xlabel("Total Consumption (Kg)")
plt.ylabel("Food Name")
plt.title("Top 10 Most Consumed Foods: 2010-11")
plt.show()

# %%
# Select the top 10 most consumed foods
top_10_foods3 = sorted_sums3.nlargest(10)
# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_foods3.values, y=top_10_foods3.index, hue=top_10_foods3.index, palette="Blues_r", legend=False)
# Labels and title
plt.xlabel("Total Consumption (Kg)")
plt.ylabel("Food Name")
plt.title("Top 10 Most Consumed Foods: 2011-12")
plt.show()

# %%
# Select the top 10 most consumed foods
top_10_foods6 = sorted_sums6.nlargest(10)
# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_foods6.values, y=top_10_foods6.index, hue=top_10_foods6.index, palette="Blues_r", legend=False)
# Labels and title
plt.xlabel("Total Consumption (Kg)")
plt.ylabel("Food Name")
plt.title("Top 10 Most Consumed Foods: 2013-14")
plt.show()

# %%
# Select the top 10 most consumed foods
top_10_foods1 = sorted_sums1.nlargest(10)
# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_foods1.values, y=top_10_foods1.index, hue=top_10_foods1.index, palette="Blues_r", legend=False)
# Labels and title
plt.xlabel("Total Consumption (Kg)")
plt.ylabel("Food Name")
plt.title("Top 10 Most Consumed Foods: 2015-16")
plt.show()

# %%
# Select the top 10 most consumed foods
top_10_foods7 = sorted_sums7.nlargest(10)
# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_foods7.values, y=top_10_foods7.index, hue=top_10_foods7.index, palette="Blues_r", legend=False)
# Labels and title
plt.xlabel("Total Consumption (Kg)")
plt.ylabel("Food Name")
plt.title("Top 10 Most Consumed Foods: 2018-19")
plt.show()

# %%
# Select the top 10 most consumed foods
top_10_foods8 = sorted_sums8.nlargest(10)
# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_foods8.values, y=top_10_foods8.index, hue=top_10_foods8.index, palette="Blues_r", legend=False)
# Labels and title
plt.xlabel("Total Consumption (Kg)")
plt.ylabel("Food Name")
plt.title("Top 10 Most Consumed Foods: 2019-20")
plt.show()

# %% [markdown]
# ### Price Trends Over Time

# %%
# List of datasets
price_dfs = [ugd4_p, ugd2_p, ugd5_p, ugd3_p, ugd6_p, ugd_p, ugd7_p, ugd8_p]
years = ['2005-06', '2009-10', '2010-11', '2011-12', '2013-14', '2015-16', '2018-19', '2019-20']

# Aggregate prices for selected staple foods
staple_foods = ['Matoke', 'Sweet Potatoes (fresh)', 'Cassava (fresh)', 'Cassava (dry)', 'Maize (flour)']

# Extract median prices over time
price_data = []
for df, year in zip(price_dfs, years):
    for food in staple_foods:
        if food in df.index.get_level_values('j'):
            median_price = df.loc[food].median().median()
            price_data.append({'Year': year, 'Food': food, 'Price': median_price})

# Convert to DataFrame
price_df = pd.DataFrame(price_data)

# Plot
plt.figure(figsize=(10,6))
sns.lineplot(data=price_df, x='Year', y='Price', hue='Food', marker='o')
plt.title('Price Trends of Staple Foods Over Time')
plt.xlabel('Year')
plt.ylabel('Median Price (UGX per Kg)')
plt.xticks(rotation=45)
plt.legend(title="Food Item")
plt.show()

# %% [markdown]
# ### Inflation-Adjusted Prices

# %%
# Normalize prices to 2005-06 as base (set it to 100)
base_prices = price_df[price_df['Year'] == '2005-06'].set_index('Food')['Price']
price_df['Inflation Adjusted Price'] = price_df.apply(lambda row: (row['Price'] / base_prices[row['Food']]) * 100 if row['Food'] in base_prices else None, axis=1)

# Plot
plt.figure(figsize=(10,6))
sns.lineplot(data=price_df, x='Year', y='Inflation Adjusted Price', hue='Food', marker='o')
plt.title('Inflation-Adjusted Prices of Staple Foods Over Time')
plt.xlabel('Year')
plt.ylabel('Price Index (Base Year = 100)')
plt.xticks(rotation=45)
plt.legend(title="Food Item")
plt.show()

# %% [markdown]
# ### Expenditure Breakdown by Category

# %%
expenditure_dfs = [ugd4_x, ugd2_x, ugd5_x, ugd3_x, ugd6_x, ugd_x, ugd7_x, ugd8_x]
category_data = []

# Filter expenditure data for only staple foods and aggregate
for df, year in zip(expenditure_dfs, years):
    df_filtered = df[staple_foods]  # Keep only the staple foods
    category_sums = df_filtered.sum().reset_index()
    category_sums.columns = ['Food', 'Expenditure']
    category_sums['Year'] = year
    category_data.append(category_sums)

# Combine all years into one DataFrame
expenditure_df = pd.concat(category_data)

# Plot
plt.figure(figsize=(12,6))
sns.barplot(data=expenditure_df, x='Year', y='Expenditure', hue='Food')
plt.title('Food Expenditure Over Time of Staple Foods')
plt.xlabel('Year')
plt.ylabel('Total Expenditure (UGX)')
plt.xticks(rotation=45)
plt.legend(title="Food Category", bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# ### Nutrient Sufficiency Over Time

# %%
# Read in the nutrient ratio data for each year
nutrient_data = {
    '2005-06': pd.read_csv('Nutrient Data/05-06 Nutrient Data.csv'),
    '2009-10': pd.read_csv('Nutrient Data/09-10 Nutrient Data.csv'),
    '2010-11': pd.read_csv('Nutrient Data/10-11 Nutrient Data.csv'),
    '2011-12': pd.read_csv('Nutrient Data/11-12 Nutrient Data.csv'),
    '2013-14': pd.read_csv('Nutrient Data/13-14 Nutrient Data.csv'),
    '2015-16': pd.read_csv('Nutrient Data/15-16 Nutrient Data.csv'),
    '2018-19': pd.read_csv('Nutrient Data/18-19 Nutrient Data.csv'),
    '2019-20': pd.read_csv('Nutrient Data/19-20 Nutrient Data.csv'),
}

# %%
# List of nutrients to analyze
nutrients = ['Energy', 'Protein', 'Fiber', 'Calcium', 'Iron']
# Create a dictionary to hold the nutrient ratios per year for each nutrient
nutrient_ratios = {nutrient: {} for nutrient in nutrients}
# Loop through each nutrient and calculate the ratio for each year
for nutrient in nutrients:
    for year, df in nutrient_data.items():
        nutrient_ratios[nutrient][year] = df[nutrient].mean() 
# Create a plot
plt.figure(figsize=(10, 6))
# Plot each nutrient's ratio over the years
for nutrient in nutrients:
    plt.plot(nutrient_ratios[nutrient].keys(), nutrient_ratios[nutrient].values(), marker='o', linestyle='-', label=f'{nutrient}')
# Customize plot
plt.title('Comparison of Nutrient Purchase-to-Requirement Ratios Over the Years')
plt.xlabel('Year')
plt.ylabel('Purchase-to-Requirement Ratio')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
# Display
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Total Nutrient Sufficiency Across Years

# %% [markdown]
# Same as above but considering all nutrients, adding their respective average ratios, and dividing by the total number of nutrients (so that we can still observe data relation to a ratio of 1).

# %%
# Calculate the total nutrient sufficiency by averaging the sum of all nutrients' mean ratios
total_sufficiency = {}

for year, df in nutrient_data.items():
    # Calculate the mean ratio for each nutrient and sum them
    total_mean = df[nutrients].mean().sum()
    # Divide the total sum by the number of nutrients to get the average sufficiency
    total_sufficiency[year] = total_mean / len(nutrients)

# Plot the total nutrient sufficiency over the years
plt.figure(figsize=(10, 6))
plt.plot(total_sufficiency.keys(), total_sufficiency.values(), marker='o', linestyle='-', color='purple')
plt.title('Average Total Nutrient Purchase-to-Requirement Sufficiency Across Years')
plt.xlabel('Year')
plt.ylabel('Average Total Nutrient Sufficiency (Mean Purchase-to-Requirement Ratio)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Nutrient Ratios Per Year

# %%
# Prepare the data for stacked bar plot
stacked_data = pd.DataFrame(columns=nutrients, index=nutrient_data.keys())

for year, df in nutrient_data.items():
    for nutrient in nutrients:
        stacked_data.loc[year, nutrient] = df[nutrient].mean()  # Use mean for the ratio

# Plot the stacked bar plot
stacked_data.plot(kind='bar', stacked=True, figsize=(12, 8), colormap='Set3')
plt.title('Stacked Bar Plot of Nutrient Purchase-to-Requirement Ratios by Year')
plt.xlabel('Year')
plt.ylabel('Purchase-to-Requirement Ratio')
plt.xticks(rotation=45)
plt.tight_layout()
plt.
plt.show()
